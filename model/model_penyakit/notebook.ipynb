# %% [markdown]
# # Cat Breeds Classification

# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Library

# %%
# %pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.6)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (2.0.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.13)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.14.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.72.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.22.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 8.6 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.34.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0

# %%
# ==== Built-in Python Modules ====
import os
import sys
import shutil
import glob
import random
import json
import xml.etree.ElementTree as ET
from collections import defaultdict
from pathlib import Path
from IPython.display import Image, display

# ==== Data Manipulation & Analysis ====
import numpy as np
import pandas as pd

# ==== Visualization ====
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns

# ==== OpenCV ====
import cv2

# ==== Scikit-learn ====
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score
)

# ==== TensorFlow & Keras ====
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau
)

# ==== TensorFlow.js ====
import tensorflowjs as tfjs

print("=== Modules Loaded ===")
# Out:
# === Modules Loaded ===

# %% [markdown]
# ## Data Getting

# %%
# Path to the zip file in your Google Drive
zip_file_path = '/content/drive/MyDrive/dicoding/capstone/inu-dh.v4i.voc.zip'

# Directory where you want to extract the contents
extract_dir = '/content/dataset'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
shutil.unpack_archive(zip_file_path, extract_dir)

print(f"File extracted to: {extract_dir}")
# Out:
# File extracted to: /content/dataset

# %%
# --- Konfigurasi ---
original_root = "dataset"
split_root = "dataset_split"
split_ratio = {"train": 0.8, "valid": 0.1, "test": 0.1}
seed = 42

# Mapping label serupa ke satu label utama (tetap digunakan)
label_mapping = {
    "Scabies": "Scabies",
    "scabies": "Scabies",
    "deteksi scabies - v3 2024-07-29 3-22pm": "Scabies",
    "Jamur": "Jamur",
    "demodicosis": "Demodicosis",
    "dermatitis": "Dermatitis",
    "flea_allergy": "Flea_Allergy",
    "ringworm": "Ringworm",
}

def parse_voc_xml(xml_file):
    """
    Mengekstrak informasi dari satu file XML PASCAL VOC.
    """
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Ambil info dasar gambar
    filename = root.find('filename').text
    size = root.find('size')
    width = int(size.find('width').text)
    height = int(size.find('height').text)

    # Ekstrak semua objek (bounding box)
    objects = []
    for member in root.findall('object'):
        original_class_name = member.find('name').text
        # Normalisasi nama kelas menggunakan mapping
        normalized_class_name = label_mapping.get(original_class_name.strip(), original_class_name.strip())

        bndbox = member.find('bndbox')
        objects.append({
            'class': normalized_class_name,
            'xmin': int(bndbox.find('xmin').text),
            'ymin': int(bndbox.find('ymin').text),
            'xmax': int(bndbox.find('xmax').text),
            'ymax': int(bndbox.find('ymax').text),
        })

    return filename, width, height, objects

# --- Gabungkan semua data anotasi dari XML ---
print("--- Memulai Proses Penggabungan Anotasi dari XML ---")

# Hapus direktori lama jika ada untuk memulai dari awal
if os.path.exists(split_root):
    shutil.rmtree(split_root)

all_image_data = []
all_annotations_for_csv = []

for split_name in ["train", "valid", "test"]:
    split_dir = os.path.join(original_root, split_name)
    if not os.path.isdir(split_dir):
        print(f"Peringatan: Direktori '{split_dir}' tidak ditemukan, dilewati.")
        continue

    # Cari semua file .xml di direktori
    xml_files = glob.glob(os.path.join(split_dir, '*.xml'))
    print(f"\nMenemukan {len(xml_files)} file XML di '{split_dir}'")

    for xml_file in xml_files:
        try:
            filename, width, height, objects = parse_voc_xml(xml_file)
            image_path = os.path.join(split_dir, filename)

            # Pastikan file gambar yang sesuai ada
            if not os.path.exists(image_path):
                # Coba cari dengan ekstensi lain
                base, _ = os.path.splitext(image_path)
                found = False
                for ext in ['.jpg', '.jpeg', '.png']:
                    if os.path.exists(base + ext):
                        image_path = base + ext
                        filename = os.path.basename(image_path)
                        found = True
                        break
                if not found:
                    print(f"Peringatan: File gambar untuk '{filename}' tidak ditemukan. Anotasi dilewati.")
                    continue

            # Dapatkan semua kelas unik yang dinormalisasi untuk gambar ini
            unique_classes = sorted(list(set([obj['class'] for obj in objects])))

            image_record = {
                'original_path': image_path,
                'xml_path': xml_file,
                'filename': filename,
                'width': width,
                'height': height,
                'classes': unique_classes # Menyimpan daftar kelas
            }
            all_image_data.append(image_record)

            # Siapkan data untuk CSV anotasi final
            for obj in objects:
                all_annotations_for_csv.append({
                    'filename': filename,
                    'width': width,
                    'height': height,
                    'class': obj['class'],
                    'xmin': obj['xmin'],
                    'ymin': obj['ymin'],
                    'xmax': obj['xmax'],
                    'ymax': obj['ymax']
                })
        except Exception as e:
            print(f"Error memproses file {xml_file}: {e}")

print(f"\nTotal gambar yang ditemukan dan diproses: {len(all_image_data)}")

# --- Split data secara acak ---
print("\n--- Memulai Proses Pemisahan Data ---")
random.seed(seed)
random.shuffle(all_image_data)

total = len(all_image_data)
train_end = int(total * split_ratio["train"])
val_end = train_end + int(total * split_ratio["valid"])

splits = {
    "train": all_image_data[:train_end],
    "valid": all_image_data[train_end:val_end],
    "test": all_image_data[val_end:]
}

# --- Simpan ke struktur direktori baru ---
print("\n--- Menyimpan Hasil Pemisahan ke Folder ---")
final_counts = defaultdict(lambda: defaultdict(int))

for split_name, records in splits.items():
    split_dir_out = os.path.join(split_root, split_name)
    os.makedirs(split_dir_out, exist_ok=True)
    print(f"Memproses dan menyalin file untuk split: {split_name}...")

    for record in records:
        # Salin file gambar
        shutil.copy2(record['original_path'], os.path.join(split_dir_out, record['filename']))
        # Salin file XML
        xml_filename = os.path.basename(record['xml_path'])
        shutil.copy2(record['xml_path'], os.path.join(split_dir_out, xml_filename))

        # Hitung distribusi kelas
        for class_name in record['classes']:
            final_counts[split_name][class_name] += 1

# --- Buat file anotasi CSV gabungan ---
annotations_df = pd.DataFrame(all_annotations_for_csv)
# Pastikan urutan kolom sesuai untuk kemudahan pembacaan
annotations_df = annotations_df[['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']]
output_csv_path = os.path.join(split_root, "annotations.csv")
annotations_df.to_csv(output_csv_path, index=False)

print(f"\nFile anotasi gabungan berhasil disimpan di: {output_csv_path}")

print("\nSelesai! Ringkasan Hasil:")
print(f"Total gambar yang diproses: {total}")
for s in ["train", "valid", "test"]:
    print(f"-> {s.capitalize()}: {len(splits[s])} gambar")

print("\nDistribusi gambar per kelas di setiap split (sebuah gambar bisa masuk beberapa kelas):")
for split_name, counts in final_counts.items():
    print(f"\n--- {split_name.upper()} ---")
    sorted_counts = sorted(counts.items())
    for label, count in sorted_counts:
        print(f"  {label}: {count} gambar")
# Out:
# --- Memulai Proses Penggabungan Anotasi dari XML ---
#
# Menemukan 4232 file XML di 'dataset/train'
#
# Menemukan 1507 file XML di 'dataset/valid'
#
# Menemukan 1506 file XML di 'dataset/test'
#
# Total gambar yang ditemukan dan diproses: 7245
#
# --- Memulai Proses Pemisahan Data ---
#
# --- Menyimpan Hasil Pemisahan ke Folder ---
# Memproses dan menyalin file untuk split: train...
# Memproses dan menyalin file untuk split: valid...
# Memproses dan menyalin file untuk split: test...
#
# File anotasi gabungan berhasil disimpan di: dataset_split/annotations.csv
#
# Selesai! Ringkasan Hasil:
# Total gambar yang diproses: 7245
# -> Train: 5796 gambar
# -> Valid: 724 gambar
# -> Test: 725 gambar
#
# Distribusi gambar per kelas di setiap split (sebuah gambar bisa masuk beberapa kelas):
#
# --- TRAIN ---
#   Demodicosis: 965 gambar
#   Dermatitis: 692 gambar
#   Flea_Allergy: 473 gambar
#   Jamur: 212 gambar
#   Ringworm: 1240 gambar
#   Scabies: 2227 gambar
#
# --- VALID ---
#   Demodicosis: 115 gambar
#   Dermatitis: 85 gambar
#   Flea_Allergy: 59 gambar
#   Jamur: 30 gambar
#   Ringworm: 166 gambar
#   Scabies: 272 gambar
#
# --- TEST ---
#   Demodicosis: 111 gambar
#   Dermatitis: 112 gambar
#   Flea_Allergy: 61 gambar
#   Jamur: 26 gambar
#   Ringworm: 149 gambar
#   Scabies: 272 gambar

# %% [markdown]
# ## Modeling

# %%
# --- Konfigurasi ---
DATA_ROOT = "dataset_split"
TRAIN_DIR = os.path.join(DATA_ROOT, "train")
VALID_DIR = os.path.join(DATA_ROOT, "valid")
TEST_DIR = os.path.join(DATA_ROOT, "test")
# File CSV yang berisi semua informasi bounding box
ANNOTATIONS_CSV = os.path.join(DATA_ROOT, "annotations.csv")
BEST_MODEL_PATH = "cat_disease.h5"

# %%
# Parameter Model & Pelatihan
IMG_WIDTH, IMG_HEIGHT = 128, 128
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001

# %%
# --- Mempersiapkan Data ---
def load_and_prepare_dataframes(annotations_path, train_dir, valid_dir, test_dir):
    if not os.path.exists(annotations_path):
        print(f"KESALAHAN: File anotasi '{annotations_path}' tidak ditemukan.")
        sys.exit()

    master_df = pd.read_csv(annotations_path)

    # Get file lists from directories
    train_files = {f for f in os.listdir(train_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))}
    valid_files = {f for f in os.listdir(valid_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))}
    test_files = {f for f in os.listdir(test_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))}

    # Filter dataframes
    train_df = master_df[master_df['filename'].isin(train_files)].copy()
    valid_df = master_df[master_df['filename'].isin(valid_files)].copy()
    test_df = master_df[master_df['filename'].isin(test_files)].copy()

    # Create class mapping from all unique classes found
    all_classes = sorted(master_df['class'].unique())
    class_to_int = {label: i for i, label in enumerate(all_classes)}

    # Proses semua dataframe dalam satu loop
    for df, dir_path in [(train_df, train_dir), (valid_df, valid_dir), (test_df, test_dir)]:
        if df.empty: continue
        df['filepath'] = df['filename'].apply(lambda f: os.path.join(dir_path, f))
        df['class_id'] = df['class'].map(class_to_int)
        df['xmin_norm'] = df['xmin'] / df['width']
        df['ymin_norm'] = df['ymin'] / df['height']
        df['xmax_norm'] = df['xmax'] / df['width']
        df['ymax_norm'] = df['ymax'] / df['height']

    return train_df, valid_df, test_df, class_to_int

# %%
# Custom Data Generator for Object Detection
class ObjectDetectionGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, class_map, batch_size=32, target_size=(128, 128), shuffle=True):
        self.image_files = df['filename'].unique()
        self.df = df.set_index('filename')
        self.class_map = class_map
        self.num_classes = len(class_map)
        self.batch_size = batch_size
        self.target_size = target_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        batch_filenames = self.image_files[index*self.batch_size:(index+1)*self.batch_size]
        X, y_class, y_bbox = self.__data_generation(batch_filenames)
        return X, {'class_output': y_class, 'bbox_output': y_bbox}

    def on_epoch_end(self):
        self.indices = np.arange(len(self.image_files))
        if self.shuffle:
            np.random.shuffle(self.indices)
        self.image_files = self.image_files[self.indices]

    def __data_generation(self, batch_filenames):
        X = np.empty((self.batch_size, *self.target_size, 3))
        y_bbox = np.empty((self.batch_size, 4))
        y_class = np.empty((self.batch_size, self.num_classes))

        for i, filename in enumerate(batch_filenames):
            annotations = self.df.loc[filename]
            if isinstance(annotations, pd.DataFrame):
                annotation = annotations.iloc[0]
            else:
                annotation = annotations
            img_path = annotation['filepath']
            image = load_img(img_path, target_size=self.target_size)
            X[i,] = img_to_array(image) / 255.0
            y_bbox[i,] = [annotation['xmin_norm'], annotation['ymin_norm'], annotation['xmax_norm'], annotation['ymax_norm']]
            y_class[i,] = tf.keras.utils.to_categorical(annotation['class_id'], num_classes=self.num_classes)

        return X, y_class, y_bbox

# %%
# Membangun Model
def create_object_detection_model(input_shape=(224, 224, 3), num_classes=2):

    # Base Model (Backbone)
    base_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = False

    # Input
    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=False)

    # Head Model
    x = Flatten(name="flatten")(x)
    x = Dense(128, activation="relu")(x)
    x = Dropout(0.5)(x)

    # Bounding Box Regression Head
    bbox_output = Dense(4, activation='sigmoid', name='bbox_output')(x)

    # Classification Head
    class_output = Dense(num_classes, activation='softmax', name='class_output')(x)

    # Final Model
    model = Model(inputs=inputs, outputs=[class_output, bbox_output])
    return model

# %%
print("--- Memuat dan Mempersiapkan Dataset ---")
train_df, val_df, test_df, class_map = load_and_prepare_dataframes(ANNOTATIONS_CSV, TRAIN_DIR, VALID_DIR, TEST_DIR)
num_classes = len(class_map)

if train_df.empty or val_df.empty:
    print("KESALAHAN: Gagal memuat data latih atau validasi.")
    sys.exit()

print(f"\nKelas yang ditemukan: {class_map}")
print(f"Total data latih: {len(train_df['filename'].unique())} gambar")
print(f"Total data validasi: {len(val_df['filename'].unique())} gambar")
print(f"Total data tes: {len(test_df['filename'].unique())} gambar")
# Out:
# --- Memuat dan Mempersiapkan Dataset ---
#
# Kelas yang ditemukan: {'Demodicosis': 0, 'Dermatitis': 1, 'Flea_Allergy': 2, 'Jamur': 3, 'Ringworm': 4, 'Scabies': 5}
# Total data latih: 5796 gambar
# Total data validasi: 724 gambar
# Total data tes: 725 gambar

# %%
train_generator = ObjectDetectionGenerator(train_df, class_map, batch_size=BATCH_SIZE)
val_generator = ObjectDetectionGenerator(val_df, class_map, batch_size=BATCH_SIZE, shuffle=False)

print("\n--- Membangun Model ---")
model = create_object_detection_model(input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), num_classes=num_classes)

losses = {
    'class_output': 'categorical_crossentropy',
    'bbox_output': 'mean_squared_error'}

optimizer = Adam(learning_rate=LEARNING_RATE)

model.compile(optimizer=optimizer, loss=losses, metrics={'class_output': 'accuracy'})
model.summary()

checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='min'
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    verbose=1,
    min_lr=1e-6,
    mode='min'
)

callbacks_list = [checkpoint, early_stopping, reduce_lr]
# Out:
# --- Membangun Model ---
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_1… │ (None, 4, 4,      │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 20480)     │          0 │ mobilenetv2_1.00… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │  2,621,568 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class_output        │ (None, 6)         │        774 │ dropout[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bbox_output (Dense) │ (None, 4)         │        516 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,880,842 (18.62 MB)
#  Trainable params: 2,622,858 (10.01 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
print("\n--- Memulai Pelatihan Model ---")
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    verbose=1,
    callbacks=callbacks_list
)
print(f"\nModel terbaik telah disimpan di '{BEST_MODEL_PATH}'.")
# Out:
# --- Memulai Pelatihan Model ---
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - bbox_output_loss: 0.1536 - class_output_accuracy: 0.5574 - class_output_loss: 2.0164 - loss: 2.1700
# Epoch 1: val_loss improved from inf to 0.79673, saving model to cat_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - bbox_output_loss: 0.1535 - class_output_accuracy: 0.5578 - class_output_loss: 2.0123 - loss: 2.1657 - val_bbox_output_loss: 0.0744 - val_class_output_accuracy: 0.7457 - val_class_output_loss: 0.7224 - val_loss: 0.7967 - learning_rate: 0.0010
# Epoch 2/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - bbox_output_loss: 0.0865 - class_output_accuracy: 0.7029 - class_output_loss: 0.7843 - loss: 0.8708
# Epoch 2: val_loss improved from 0.79673 to 0.78136, saving model to cat_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 122ms/step - bbox_output_loss: 0.0864 - class_output_accuracy: 0.7030 - class_output_loss: 0.7843 - loss: 0.8707 - val_bbox_output_loss: 0.0664 - val_class_output_accuracy: 0.7628 - val_class_output_loss: 0.7150 - val_loss: 0.7814 - learning_rate: 0.0010
# Epoch 3/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - bbox_output_loss: 0.0526 - class_output_accuracy: 0.7323 - class_output_loss: 0.6963 - loss: 0.7488
# Epoch 3: val_loss improved from 0.78136 to 0.63299, saving model to cat_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - bbox_output_loss: 0.0525 - class_output_accuracy: 0.7324 - class_output_loss: 0.6962 - loss: 0.7487 - val_bbox_output_loss: 0.0383 - val_class_output_accuracy: 0.7940 - val_class_output_loss: 0.5947 - val_loss: 0.6330 - learning_rate: 0.0010
# Epoch 4/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - bbox_output_loss: 0.0410 - class_output_accuracy: 0.7647 - class_output_loss: 0.5921 - loss: 0.6330
# Epoch 4: val_loss improved from 0.63299 to 0.55717, saving model to cat_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 119ms/step - bbox_output_loss: 0.0410 - class_output_accuracy: 0.7647 - class_output_loss: 0.5920 - loss: 0.6330 - val_bbox_output_loss: 0.0376 - val_class_output_accuracy: 0.8097 - val_class_output_loss: 0.5195 - val_loss: 0.5572 - learning_rate: 0.0010
# Epoch 5/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - bbox_output_loss: 0.0382 - class_output_accuracy: 0.7826 - class_output_loss: 0.5488 - loss: 0.5870
# Epoch 5: val_loss did not improve from 0.55717
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - bbox_output_loss: 0.0382 - class_output_accuracy: 0.7826 - class_output_loss: 0.5488 - loss: 0.5870 - val_bbox_output_loss: 0.0351 - val_class_output_accuracy: 0.8224 - val_class_output_loss: 0.5665 - val_loss: 0.6016 - learning_rate: 0.0010
# Epoch 6/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - bbox_output_loss: 0.0367 - class_output_accuracy: 0.8079 - class_output_loss: 0.4980 - loss: 0.5347
# Epoch 6: val_loss improved from 0.55717 to 0.48172, saving model to cat_disease.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 119ms/step - bbox_output_loss: 0.0367 - class_output_accuracy: 0.8079 - class_output_loss: 0.4980 - loss: 0.5347 - val_bbox_output_loss: 0.0341 - val_class_output_accuracy: 0.8381 - val_class_output_loss: 0.4476 - val_loss: 0.4817 - learning_rate: 0.0010
# Epoch 7/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - bbox_output_loss: 0.0349 - class_output_accuracy: 0.8176 - class_output_loss: 0.4540 - loss: 0.4889
# Epoch 7: val_loss did not improve from 0.48172
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 122ms/step - bbox_output_loss: 0.0349 - class_output_accuracy: 0.8176 - class_output_loss: 0.4541 - loss: 0.4890 - val_bbox_output_loss: 0.0335 - val_class_output_accuracy: 0.8352 - val_class_output_loss: 0.4832 - val_loss: 0.5166 - learning_rate: 0.0010
# Epoch 8/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - bbox_output_loss: 0.0345 - class_output_accuracy: 0.8234 - class_output_loss: 0.4271 - loss: 0.4616
# Epoch 8: val_loss did not improve from 0.48172
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 39s 113ms/step - bbox_output_loss: 0.0345 - class_output_accuracy: 0.8234 - class_output_loss: 0.4272 - loss: 0.4617 - val_bbox_output_loss: 0.0332 - val_class_output_accuracy: 0.8509 - val_class_output_loss: 0.4841 - val_loss: 0.5173 - learning_rate: 0.0010
# Epoch 9/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - bbox_output_loss: 0.0345 - class_output_accuracy: 0.8382 - class_output_loss: 0.4084 - loss: 0.4429
# Epoch 9: val_loss did not improve from 0.48172
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 119ms/step - bbox_output_loss: 0.0345 - class_output_accuracy: 0.8382 - class_output_loss: 0.4084 - loss: 0.4429 - val_bbox_output_loss: 0.0331 - val_class_output_accuracy: 0.8594 - val_class_output_loss: 0.5130 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 10/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - bbox_output_loss: 0.0333 - class_output_accuracy: 0.8450 - class_output_loss: 0.3821 - loss: 0.4153
# Epoch 10: val_loss did not improve from 0.48172
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 21s 118ms/step - bbox_output_loss: 0.0333 - class_output_accuracy: 0.8450 - class_output_loss: 0.3819 - loss: 0.4152 - val_bbox_output_loss: 0.0325 - val_class_output_accuracy: 0.8665 - val_class_output_loss: 0.5005 - val_loss: 0.5330 - learning_rate: 2.0000e-04
# Epoch 11/50
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - bbox_output_loss: 0.0331 - class_output_accuracy: 0.8506 - class_output_loss: 0.3317 - loss: 0.3648
# Epoch 11: val_loss did not improve from 0.48172
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - bbox_output_loss: 0.0331 - class_output_accuracy: 0.8506 - class_output_loss: 0.3317 - loss: 0.3648 - val_bbox_output_loss: 0.0326 - val_class_output_accuracy: 0.8693 - val_class_output_loss: 0.4885 - val_loss: 0.5211 - learning_rate: 2.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# Model terbaik telah disimpan di 'cat_disease.h5'.

# %%
# Save as TensorFlow SavedModel format
saved_model_dir = 'cat_disease_savedmodel'
model.export(saved_model_dir)
print(f"Model saved in SavedModel format at: {saved_model_dir}")

# Save as TensorFlow.js format
tfjs_model_dir = 'cat_disease_tfjs'
tfjs.converters.save_keras_model(model, tfjs_model_dir)
print(f"Model saved in TensorFlow.js format at: {tfjs_model_dir}")
# Out:
# Saved artifact at 'cat_disease_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   List[TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)]
# Captures:
#   134824617514512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617511440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615988304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617518160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617515664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617522000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615987728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615990032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615999440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616001360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616000400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824615989648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616000016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616002960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616003536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616002768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616006416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616006608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616005264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616008720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616009104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616009296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616004112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616011408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616011216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616007568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616013328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616013136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616010256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616015056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616015440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616015248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616014096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616016784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616016208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616017360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616014480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616016592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617526480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617526672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617528016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617528400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617529936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617530320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617530512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617526096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617531856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617532240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617532624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617532432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617527632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617534352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617535696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617531472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617538000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617538384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617533392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617539536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617540304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617535312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617541456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617537232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617541072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824617539152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616821776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616825232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616825040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616821200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616826384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616826768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616827152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616826960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616828304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616828688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616828880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616824080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616830224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616830608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616830992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616826000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616832144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616832528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616832912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616832720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616827920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616834064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616834448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616834832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616834640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616835984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616835600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616833680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616836560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616831760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824616835216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613971152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613970000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613970192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613972688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613973072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613973456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613974608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613974992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613975376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613975184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613970768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613976528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613976912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613977296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613972304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613978448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613978832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613974224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613980368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613980752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613976144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613982288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613982672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613983056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613982864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613978064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613984208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613984592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613984976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613986128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613981904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614331024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613985744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824613983824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614332176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614332560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614332944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614332752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614331408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614334096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614334480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614334864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614334672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614330448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614336016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614336400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614336784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614336592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614331792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614337936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614338320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614338704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614338512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614333712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614339856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614340240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614340624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614340432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614335632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614341776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614342160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614342544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614342352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614337552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614343696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614344080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614344464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614344272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614339472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614345616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614345232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614343312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614346192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614341392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824614344848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604271824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604270672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604272016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604273744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604274128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604273936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604275664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604272976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604281424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604281808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604281616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604282960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604283728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604283536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604284880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604285648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604285456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604271056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604829264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604830224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134824604830992: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved in SavedModel format at: cat_disease_savedmodel
# failed to lookup keras version from the file,
#     this is likely a weight only file
# Model saved in TensorFlow.js format at: cat_disease_tfjs

# %%
# Visualisasi Hasil Pelatihan
def plot_history(history):
    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['class_output_accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_class_output_accuracy'], label='Validation Accuracy')
    plt.title('Classification Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Total Training Loss')
    plt.plot(history.history['val_loss'], label='Total Validation Loss')
    plt.title('Total Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
# Evaluasi Model pada Data Tes
def evaluate_on_test_data(model_path, test_df, class_map):
    if test_df.empty:
        print("\nTidak ada data tes untuk dievaluasi. Melewatkan langkah ini.")
        return

    print("\n--- Mengevaluasi Model pada Data Tes ---")

    # Buat generator untuk data tes
    test_generator = ObjectDetectionGenerator(test_df, class_map, batch_size=BATCH_SIZE, shuffle=False)

    # Muat model terbaik
    best_model = tf.keras.models.load_model(model_path)

    # Buat prediksi pada data tes
    predictions = best_model.predict(test_generator, verbose=1)
    pred_classes_probs = predictions[0]

    # Dapatkan label prediksi (kelas dengan probabilitas tertinggi)
    y_pred = np.argmax(pred_classes_probs, axis=1)

    # Dapatkan label sebenarnya (true labels)
    # Karena shuffle=False, urutannya cocok dengan image_files di generator
    true_df = test_df.drop_duplicates(subset='filename').set_index('filename')
    y_true = true_df.loc[test_generator.image_files]['class_id'].values[:len(y_pred)]

    class_labels = list(class_map.keys())
    # Tampilkan Classification Report
    print("\nLaporan Klasifikasi (Classification Report):")
    print(classification_report(y_true, y_pred, target_names=class_labels))

    # Tampilkan Confusion Matrix
    print("\nMatriks Konfusi (Confusion Matrix):")
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    plt.ylabel('Kelas Aktual (True Label)')
    plt.xlabel('Kelas Prediksi (Predicted Label)')
    plt.show()

# %%
# Jalankan evaluasi
evaluate_on_test_data(BEST_MODEL_PATH, test_df, class_map)
# Out:
# --- Mengevaluasi Model pada Data Tes ---
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step
#
# Laporan Klasifikasi (Classification Report):
#               precision    recall  f1-score   support
#
#  Demodicosis       0.96      0.97      0.97       101
#   Dermatitis       0.89      0.66      0.76       109
# Flea_Allergy       0.57      0.72      0.64        58
#        Jamur       0.00      0.00      0.00        26
#     Ringworm       0.81      0.91      0.85       141
#      Scabies       0.89      0.95      0.92       269
#
#     accuracy                           0.85       704
#    macro avg       0.69      0.70      0.69       704
# weighted avg       0.82      0.85      0.83       704
#
#
# Matriks Konfusi (Confusion Matrix):
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Visualisasi Prediksi tunggal (sebagai contoh)
def predict_and_visualize(model_path, image_path, class_map):
    print(f"\n--- Menjalankan Prediksi pada Gambar Contoh: {image_path} ---")
    model = tf.keras.models.load_model(model_path, compile=False)
    image = load_img(image_path, target_size=(IMG_WIDTH, IMG_HEIGHT))
    image_array = img_to_array(image) / 255.0
    image_batch = np.expand_dims(image_array, axis=0)
    pred_class, pred_bbox = model.predict(image_batch)
    class_id = np.argmax(pred_class[0])
    int_to_class = {v: k for k, v in class_map.items()}
    class_label = int_to_class[class_id]
    confidence = pred_class[0][class_id]
    xmin, ymin, xmax, ymax = pred_bbox[0]
    original_image = np.array(load_img(image_path))
    h, w, _ = original_image.shape
    xmin_abs, ymin_abs, xmax_abs, ymax_abs = int(xmin * w), int(ymin * h), int(xmax * w), int(ymax * h)

    fig, ax = plt.subplots(1, figsize=(8, 8))
    ax.imshow(original_image)
    rect = patches.Rectangle((xmin_abs, ymin_abs), xmax_abs - xmin_abs, ymax_abs - ymin_abs, linewidth=2, edgecolor='lime', facecolor='none')
    ax.add_patch(rect)
    plt.text(xmin_abs, ymin_abs - 10, f'{class_label} ({confidence:.2f})', color='white', backgroundcolor='lime', fontsize=12)
    plt.axis('off')
    plt.show()

if not test_df.empty:
    sample_image_path = test_df.iloc[np.random.randint(0, len(test_df))]['filepath']
    predict_and_visualize(BEST_MODEL_PATH, sample_image_path, class_map)
# Out:
# --- Menjalankan Prediksi pada Gambar Contoh: dataset_split/test/IMG_5195_jpeg_jpg.rf.eaf11cc399ff1f39702f200f9cd085ef.jpg ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %% [markdown]
# ## Inference

# %%
# --- Konfigurasi ---
IMG_WIDTH, IMG_HEIGHT = 128, 128

CLASS_MAP = {
    0: 'Jamur',
    1: 'Scabies',
    2: 'Demodicosis',
    3: 'Dermatitis',
    4: 'Flea_Allergy',
    5: 'Ringworm'
}

def predict_on_image(model, image_path, output_dir, confidence_threshold=0.5):
    print(f"--> Memproses: {os.path.basename(image_path)}")

    # Load gambar asli
    original_image = cv2.imread(image_path)
    if original_image is None:
        print(f"    Peringatan: Gagal memuat gambar {image_path}, dilewati.")
        return

    # Resize & normalisasi untuk model
    image_for_model = cv2.resize(original_image, (IMG_WIDTH, IMG_HEIGHT))
    image_for_model = image_for_model.astype("float32") / 255.0
    image_batch = np.expand_dims(image_for_model, axis=0)

    # Prediksi model
    pred_class_probs, _ = model.predict(image_batch)
    class_id = np.argmax(pred_class_probs[0])
    confidence = pred_class_probs[0][class_id]

    if confidence < confidence_threshold:
        print(f"    Info: Prediksi di bawah threshold ({confidence:.2f} < {confidence_threshold}). Label tidak ditambahkan.")
        label_text = "No confident prediction"
    else:
        class_label = CLASS_MAP.get(class_id, "Unknown")
        label_text = f"{class_label}: {confidence:.2%}"  # Persentase

    # Tambahkan label ke gambar
    labeled_image = original_image.copy()
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.7
    color = (0, 255, 0)
    thickness = 2
    (text_width, text_height), baseline = cv2.getTextSize(label_text, font, font_scale, thickness)
    # Comment kedua baris kode berikut
    # Jika tidak ingin menambahkan teks hasil prediksi ke gambar sama
    cv2.rectangle(labeled_image, (5, 5), (10 + text_width, 10 + text_height + baseline), (0, 255, 0), -1)
    cv2.putText(labeled_image, label_text, (10, 10 + text_height), font, font_scale, (0, 0, 0), thickness)

    # Simpan atau tampilkan
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
        output_path = os.path.join(output_dir, "pred_" + os.path.basename(image_path))
        cv2.imwrite(output_path, labeled_image)
        print(f"    Hasil disimpan di: {output_path}")
    else:
        print(f"    Prediksi: {label_text}")
        temp_output_path = "/tmp/temp_pred_" + os.path.basename(image_path)
        cv2.imwrite(temp_output_path, labeled_image)
        display(Image(filename=temp_output_path))


def run_inference(model_path, input_path, output_dir=None, threshold=0.5):
    if not os.path.exists(model_path):
        print(f"Error: File model tidak ditemukan di '{model_path}'")
        return

    if not os.path.exists(input_path):
        print(f"Error: Path input tidak ditemukan di '{input_path}'")
        return

    print("\n[INFO] Memuat model...")
    try:
        model = tf.keras.models.load_model(model_path, compile=False)
        print("[INFO] Model berhasil dimuat.")
    except Exception as e:
        print(f"Error: Gagal memuat model. Kesalahan: {e}")
        return

    if os.path.isdir(input_path):
        print(f"\n[INFO] Memproses semua gambar di direktori: {input_path}")
        image_files = [f for f in os.listdir(input_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        if not image_files:
            print("Error: Tidak ada file gambar yang ditemukan di direktori input.")
            return

        for image_file in image_files:
            full_image_path = os.path.join(input_path, image_file)
            predict_on_image(model, full_image_path, output_dir, threshold)

    elif os.path.isfile(input_path):
        print(f"\n[INFO] Memproses satu gambar: {input_path}")
        predict_on_image(model, input_path, output_dir, threshold)

    print("\n[INFO] Proses inference selesai.")


if __name__ == "__main__":
    MODEL_PATH_INPUT = "/content/cat_disease.h5"
    INPUT_PATH_INPUT = "/content/inference-1.jpg"  # atau direktori
    # OUTPUT_PATH_DIR = "/content/hasil_prediksi"  # Uncomment jika ingin menyimpan
    CONFIDENCE_THRESHOLD_INPUT = 0.5

    run_inference(
        model_path=MODEL_PATH_INPUT,
        input_path=INPUT_PATH_INPUT,
        # output_dir=OUTPUT_PATH_DIR,
        threshold=CONFIDENCE_THRESHOLD_INPUT
    )
# Out:
# [INFO] Memuat model...
# [INFO] Model berhasil dimuat.
#
# [INFO] Memproses satu gambar: /content/inference-1.jpg
# --> Memproses: inference-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#     Prediksi: Ringworm: 88.08%
# [INFO] Proses inference selesai.

# %% [markdown]
# ## Kompres dan Download Model

# %%
# !zip -r cat_disease_savedmodel.zip cat_disease_savedmodel
# !zip -r cat_disease_tfjs.zip cat_disease_tfjs
# Out:
#   adding: cat_disease_savedmodel/ (stored 0%)
#   adding: cat_disease_savedmodel/fingerprint.pb (stored 0%)
#   adding: cat_disease_savedmodel/assets/ (stored 0%)
#   adding: cat_disease_savedmodel/variables/ (stored 0%)
#   adding: cat_disease_savedmodel/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: cat_disease_savedmodel/variables/variables.index (deflated 78%)
#   adding: cat_disease_savedmodel/saved_model.pb (deflated 90%)
#   adding: cat_disease_tfjs/ (stored 0%)
#   adding: cat_disease_tfjs/group1-shard1of5.bin (deflated 7%)
#   adding: cat_disease_tfjs/group1-shard5of5.bin (deflated 7%)
#   adding: cat_disease_tfjs/group1-shard2of5.bin (deflated 7%)
#   adding: cat_disease_tfjs/model.json (deflated 97%)
#   adding: cat_disease_tfjs/group1-shard3of5.bin (deflated 7%)
#   adding: cat_disease_tfjs/group1-shard4of5.bin (deflated 7%)

# %%
from google.colab import files
files.download('cat_disease_savedmodel.zip')
files.download('cat_disease_tfjs.zip')
files.download('cat_disease.h5')
